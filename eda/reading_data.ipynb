# %% [markdown]
# # Reading Data

# %%
import pandas as pd

# %%
path = "../data"

# %%
# Read the experimental data (cross-sectional)
lalonde_exp = pd.read_csv(f"{path}/lalonde_exp.csv")

# Read the observational data from PSID (cross-sectional)
lalonde_psid = pd.read_csv(f"{path}/lalonde_psid.csv")

# Read the experimental data (panel)
lalonde_exp_panel = pd.read_csv(f"{path}/lalonde_exp_panel.csv")

# Read the observational data from PSID (panel)
lalonde_psid_panel = pd.read_csv(f"{path}/lalonde_psid_panel.csv")

# %%
lalonde_exp.head()
# Out:
#    age  education  black  hispanic  married  nodegree  re74  re75      re78  \
# 0   37         11      1         0        1         1   0.0   0.0   9930.05
# 1   22          9      0         1        0         1   0.0   0.0   3595.89
# 2   30         12      1         0        0         0   0.0   0.0  24909.50
# 3   27         11      1         0        0         1   0.0   0.0   7506.15
# 4   33          8      1         0        0         1   0.0   0.0    289.79
#
#    u74  u75  treat  id
# 0    1    1      1   1
# 1    1    1      1   2
# 2    1    1      1   3
# 3    1    1      1   4
# 4    1    1      1   5

# %%
lalonde_psid.head()
# Out:
#    age  education  black  hispanic  married  nodegree  re74  re75      re78  \
# 0   37         11      1         0        1         1   0.0   0.0   9930.05
# 1   22          9      0         1        0         1   0.0   0.0   3595.89
# 2   30         12      1         0        0         0   0.0   0.0  24909.50
# 3   27         11      1         0        0         1   0.0   0.0   7506.15
# 4   33          8      1         0        0         1   0.0   0.0    289.79
#
#    u74  u75  treat  id
# 0    1    1      1   1
# 1    1    1      1   2
# 2    1    1      1   3
# 3    1    1      1   4
# 4    1    1      1   5

# %%
lalonde_exp_panel.head()
# Out:
#    year  id        re  treat  age  education  black  hispanic  married  \
# 0  1978   1   9930.05      1   37         11      1         0        1
# 1  1978   2   3595.89      1   22          9      0         1        0
# 2  1978   3  24909.50      1   30         12      1         0        0
# 3  1978   4   7506.15      1   27         11      1         0        0
# 4  1978   5    289.79      1   33          8      1         0        0
#
#    nodegree  u74  u75 uniqueid
# 0         1    1    1   1-1978
# 1         1    1    1   2-1978
# 2         0    1    1   3-1978
# 3         1    1    1   4-1978
# 4         1    1    1   5-1978

# %%
lalonde_psid_panel.head()
# Out:
#    year  id        re  treat  age  education  black  hispanic  married  \
# 0  1978   1   9930.05      1   37         11      1         0        1
# 1  1978   2   3595.89      1   22          9      0         1        0
# 2  1978   3  24909.50      1   30         12      1         0        0
# 3  1978   4   7506.15      1   27         11      1         0        0
# 4  1978   5    289.79      1   33          8      1         0        0
#
#    nodegree  u74  u75 uniqueid
# 0         1    1    1   1-1978
# 1         1    1    1   2-1978
# 2         0    1    1   3-1978
# 3         1    1    1   4-1978
# 4         1    1    1   5-1978
