# %% [markdown]
# # IPW v1: `Re78`

# %%
import sys
sys.path.append("../")

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from utils.bootstrap import bootstrap, bootstrap_experiment
from utils.prop_utils import ipw, ipw_probs

# %%
lalonde_exp = pd.read_csv("../data/lalonde_exp.csv")
lalonde_obs = pd.read_csv("../data/lalonde_psid.csv")

# %% [markdown]
# Assume $Y$ represents our outcome variable, i.e., `re78`. Our set of confounders is $Z=$ {`education, re74, re75, black, hispanic, married`}. $A$ is our intervention variable which represents `treat` or job training. Recall our backdoor estimator for our average causal effect (risk difference):
#
# \begin{align}
# E[Y^a - Y^{a'}]
# &= \sum_Z p(z) [E(Y \mid a, z) - E(Y \mid a', z)]\\
# \end{align}
#
# Our IPW formula looks like:
#
# \begin{align}
# E[Y^a]
# &= \frac{1}{N} \sum_i Y_i \cdot \frac{1(A_i = a)}{p(A_i = a \mid Z)}\\
# \end{align}
#
# Where, $p(A \mid Z)$ is effectively probability of receiving treatment. This is also a higher variance estimator because it uses less data and also it divides by a high number.

# %% [markdown]
# ## Experimental Data

# %%
ipw_results = bootstrap_experiment(
    df=lalonde_exp,
    function=ipw,
    num_exp=50,
    n=50,
    ci=95,
    treatment_col="treat",
    outcome_col="re78",
    confounder_cols=[
        "age",
        "education",
        "black",
        "hispanic",
        "married",
        "re74",
        "re75",
    ],
)
# Out:
# Running experiments: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:29<00:00,  1.67it/s]

# %%
ci_df = pd.DataFrame(ipw_results, columns=["mean", "lower_ci", "upper_ci"])
ci_df["experiment"] = range(1, len(ci_df) + 1)

plt.figure(figsize=(12, 6))

plt.plot(ci_df["experiment"], ci_df["lower_ci"], label="Lower CI 95%", marker="o")
plt.plot(ci_df["experiment"], ci_df["upper_ci"], label="Upper CI 95%", marker="o")
plt.plot(ci_df["experiment"], ci_df["mean"], label="$E[Y^a - Y^{a'}]$", marker="o")

plt.fill_between(
    ci_df["experiment"],
    ci_df["lower_ci"],
    ci_df["upper_ci"],
    color="gray",
    alpha=0.3,
    label="95% CI Range",
)

plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.xticks(ci_df["experiment"])
plt.xlabel("Experiment Number")
plt.ylabel("Confidence Interval")
plt.title("ATE using IPW (Experimental Data)")
plt.legend()
plt.show()

# %% [markdown]
# This is a high variance estimator.

# %% [markdown]
# ## Observational Data

# %%
ipw_results = bootstrap_experiment(
    df=lalonde_obs,
    function=ipw,
    num_exp=50,
    n=50,
    ci=95,
    treatment_col="treat",
    outcome_col="re78",
    confounder_cols=[
        "age",
        "education",
        "black",
        "hispanic",
        "married",
        "re74",
        "re75",
    ],
)
# Out:
# Running experiments: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 50/50 [02:53<00:00,  3.48s/it]

# %%
ci_df = pd.DataFrame(ipw_results, columns=["mean", "lower_ci", "upper_ci"])
ci_df["experiment"] = range(1, len(ci_df) + 1)

plt.figure(figsize=(10, 6))

plt.plot(ci_df["experiment"], ci_df["lower_ci"], label="Lower CI 95%", marker="o")
plt.plot(ci_df["experiment"], ci_df["upper_ci"], label="Upper CI 95%", marker="o")
plt.plot(ci_df["experiment"], ci_df["mean"], label="$E[Y^a - Y^{a'}]$", marker="o")

plt.fill_between(
    ci_df["experiment"],
    ci_df["lower_ci"],
    ci_df["upper_ci"],
    color="gray",
    alpha=0.3,
    label="95% CI Range",
)

plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.xticks(ci_df["experiment"])
plt.xlabel("Experiment Number")
plt.ylabel("Confidence Interval")
plt.title("ATE using IPW (Observational Data)")
plt.legend()
plt.show()

# %% [markdown]
# ### Why biased estimate?
#
# Let's look at the IPWs individually.

# %%
ipw_prob_results_df = ipw_probs(
    lalonde_obs,
    "treat",
    ["age", "education", "black", "hispanic", "married", "re74", "re75"],
)

# %%
lalonde_obs_ipw_df = pd.merge(lalonde_obs, ipw_prob_results_df, on=["id"])

# %%
lalonde_obs_ipw_df.groupby(["black", "hispanic", "married", "nodegree", "treat"]).agg(
    n=("ipw", "count"),
    ipw_mean=("ipw", "mean"),
    ipw_median=("ipw", "median"),
    ipw_percentile_25=("ipw", lambda x: np.percentile(x, 25)),
    ipw_percentile_75=("ipw", lambda x: np.percentile(x, 75)),
    re78_mean=("re78", "mean"),
    re78_median=("re78", "median"),
    re78_percentile_25=("re78", lambda x: np.percentile(x, 25)),
    re78_percentile_75=("re78", lambda x: np.percentile(x, 75)),
    re75_mean=("re75", "mean"),
    re75_median=("re75", "median"),
    re75_percentile_25=("re75", lambda x: np.percentile(x, 25)),
    re75_percentile_75=("re75", lambda x: np.percentile(x, 75)),
).reset_index().sort_values(["black", "hispanic", "married", "nodegree", "treat"])
# Out:
#     black  hispanic  married  nodegree  treat     n    ipw_mean  ipw_median  \
# 0       0         0        0         0      0   167    1.044615    1.001258
# 1       0         0        0         0      1     7    8.076373    6.155729
# 2       0         0        0         1      0    28    1.058451    1.019325
# 3       0         0        0         1      1     8    3.203601    2.691653
# 4       0         0        1         0      0  1225    1.003740    1.000017
# 5       0         0        1         0      1     2   29.208087   29.208087
# 6       0         0        1         1      0   365    1.005605    1.000081
# 7       0         0        1         1      1     1    9.668568    9.668568
# 8       0         1        0         0      0     3    3.642755    3.233452
# 9       0         1        0         0      1     1    1.720290    1.720290
# 10      0         1        0         1      0     3    1.888631    1.610288
# 11      0         1        0         1      1     7    1.811563    1.222350
# 12      0         1        1         0      0    42    1.019832    1.001724
# 13      0         1        1         0      1     1    6.290671    6.290671
# 14      0         1        1         1      0    33    1.039742    1.002240
# 15      0         1        1         1      1     2    3.507807    3.507807
# 16      1         0        0         0      0    59    1.605857    1.049178
# 17      1         0        0         0      1    37    1.537107    1.231150
# 18      1         0        0         1      0    73    2.310017    1.191838
# 19      1         0        0         1      1    90    1.605264    1.178117
# 20      1         0        1         0      0   234    1.036009    1.001240
# 21      1         0        1         0      1     6  257.498363    8.947603
# 22      1         0        1         1      0   258    1.051119    1.008980
# 23      1         0        1         1      1    23  313.041724    2.397705
#
#     ipw_percentile_25  ipw_percentile_75     re78_mean   re78_median  \
# 0            1.000023           1.016054  20476.281914  20132.546875
# 1            2.899475           7.564608   7337.242857   5587.500000
# 2            1.000597           1.075055  15104.001639  13225.652832
# 3            2.214345           4.261465   8870.848750   9798.875000
# 4            1.000000           1.000408  25745.981257  25195.238281
# 5           23.395067          35.021106   6209.050000   6209.050000
# 6            1.000008           1.001562  18292.392600  17732.718750
# 7            9.668568           9.668568   4232.310000   4232.310000
# 8            2.117420           4.963439  13090.194417   8275.268555
# 9            1.720290           1.720290    559.443000    559.443000
# 10           1.353713           2.284377   2709.165365      0.000000
# 11           1.138721           2.253614   8302.712857   5112.010000
# 12           1.000045           1.015020  27147.948033  24086.943359
# 13           6.290671           6.290671  10092.800000  10092.800000
# 14           1.000142           1.023610  15789.284446  16254.992188
# 15           2.479387           4.536226   4788.210000   4788.210000
# 16           1.003882           1.569170  15485.973372  14777.265625
# 17           1.155162           1.660549   7756.148027   4843.180000
# 18           1.019017           2.093607   8705.509903   7388.632812
# 19           1.112160           1.406080   4833.516567   3110.225000
# 20           1.000068           1.009751  21159.295159  20688.171875
# 21           3.397583         241.742386  12183.931667   9539.525000
# 22           1.000462           1.044509  13186.641990  11821.813477
# 23           2.151469           4.601289   7050.816609   4181.940000
#
#     re78_percentile_25  re78_percentile_75     re75_mean   re75_median  \
# 0          9605.222656        29569.308594  17215.463243  17008.064453
# 1          5045.675000        10303.300000   1628.681286      0.000000
# 2          6169.508545        19265.859863  12466.399850  10294.354492
# 3          3503.390000        13496.825000   1058.742250      0.000000
# 4         16993.855469        33426.175781  23035.823532  21546.531250
# 5          3104.525000         9313.575000    426.861500    426.861500
# 6          8866.359375        25860.214844  16520.704468  16148.709961
# 7          4232.310000         4232.310000   1713.150000   1713.150000
# 8          5966.320923        17806.604980   7781.935420     71.612900
# 9           559.443000          559.443000   1117.440000   1117.440000
# 10            0.000000         4063.748047   1253.225789   1074.193481
# 11         3738.585000         8676.785000   2114.723357      0.000000
# 12        15137.461426        33618.279297  18310.779914  16650.000000
# 13        10092.800000        10092.800000   7055.700000   7055.700000
# 14         8866.359375        20688.171875  14485.337306  11995.161133
# 15         3788.085000         5788.335000   2731.900000   2731.900000
# 16        10122.426758        22018.125977  13060.767444  13339.694336
# 17          647.205000        10976.500000    660.243270      0.000000
# 18          886.635925        11821.813477   8457.189570   7161.290527
# 19            0.000000         7494.140000   1135.088822      0.000000
# 20        13679.314941        26555.115723  17829.899132  17391.193359
# 21         2546.592500        15256.325000   4767.813167   3064.439500
# 22         7096.781738        17732.718750  12249.602297  10796.539551
# 23         1517.390000        10581.675000   3363.427565      0.000000
#
#     re75_percentile_25  re75_percentile_75
# 0          7161.290527        25601.613281
# 1             0.000000         1472.634500
# 2          4565.322754        15665.322998
# 3             0.000000         1246.236000
# 4         14322.581055        30435.484375
# 5           213.430750          640.292250
# 6          8844.193359        22916.128906
# 7          1713.150000         1713.150000
# 8            35.806450        11672.903130
# 9          1117.440000         1117.440000
# 10          537.096741         1879.838684
# 11            0.000000         2974.696750
# 12         8651.733643        24599.032227
# 13         7055.700000         7055.700000
# 14         7161.290527        18977.419922
# 15         1365.950000         4097.850000
# 16         5863.306396        17518.306641
# 17            0.000000          501.074000
# 18         3437.419434        12532.257812
# 19            0.000000         1762.855000
# 20        12373.366699        23274.193359
# 21           83.512250         9654.757500
# 22         6015.483765        16949.877930
# 23            0.000000         2906.590000

# %% [markdown]
# Looking at rows with higher weightage:
#
# | black | hispanic | married | nodegree | treat | n  | $\hat{ipw}$     | $\hat{re_{78}}$     | $\hat{re_{75}}$    | $\hat{re_{78}} - \hat{re_{75}}$ |
# |-------|----------|---------|----------|-------|----|--------------|---------------|--------------|---------------------|
# | 1     | 0        | 1       | 1        | 1     | 23 | 313.041724   | 7050.816609   | 3363.427565  | 3687.389044         |
# | 1     | 0        | 1       | 0        | 1     | 6  | 257.498363   | 12183.93167   | 4767.813167  | 7416.1185           |
# | 0     | 0        | 1       | 0        | 1     | 2  | 29.208087    | 6209.05       | 426.8615     | 5782.1885           |
# | ...   | ...      | ...     | ...      | ...   | ...| ...          | ...           | ...          | ...                 |
# | 0     | 1        | 0       | 0        | 0     | 3  | 3.642755     | 13090.19442   | 7781.93542   | 5308.258997         |
# | ...   | ...      | ...     | ...      | ...   | ...| ...          | ...           | ...          | ...                 |
# | 1     | 0        | 0       | 1        | 0     | 73 | 2.310017     | 8705.509903   | 8457.18957   | 248.320333          |
# | 0     | 1        | 0       | 1        | 0     | 3  | 1.888631     | 2709.165365   | 1253.225789  | 1455.939576         |
#
#
# * We can see that a bulk of our means would be represented by these rows for the treatment and the non-treatment group.
# * While this does alleviate confounding, it skews the earnings to a lower value to the treatment group and a higher value for the non-treatment group.
# * We could say that this might be due to job training, but upon a closer look we can see that the difference in revenue for the treatment group is much higher.
# * This tells us that the non-treatment group (in the observable) are typically starting out with a higher income in 1974.
